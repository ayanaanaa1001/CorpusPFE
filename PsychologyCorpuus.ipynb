# %%
with open('/content/rData.txt', 'r', encoding='utf-8') as file:
    text_content = file.read()

# %%
import re

def clean_text_file(input_file, output_file):
    with open(input_file, 'r', encoding='utf-8') as file:
        text_content = file.read()

    # List of the irrelevant texts or sentences to remove
    irrelevant_phrases = [
    "MSD الإرشادي إصدار المُستخدِم",
    "honeypot link",
    "skip to main content",
    "أدلة MSD",
    "إصدار المُستخدِم",
    "الموارد",
    "التعليق",
    "تمت مراجعته",
    "شوّال 1444",
    "احصل على الحقائق السريعة",
    "Test your Knowledge",
    "Take a Quiz!",
    "محفوظة لشركة",
    "© 2025",
    "محفوظة لشركة Merck & Co., Inc., Rahway, NJ, USA والشركات التابعة لها. جميع الحقوق محفوظة.",
    "إخلاء المسؤولية",
    "التصاريح",
    "الخصوصية",
    "شروط الاستخدام",
    "الترخيص",
    "تواصل معنا",
    "دليل الأطباء البيطريين",
    "للمزيد من المعلومات",
    "24/7",
    "أطباء متوفرون لمساعدتك",
    "تحدث مع طبيب الآن!",
    "طبيبك معك أينما كنت",
    "تسجيل دخول",
    "إبحث",
    "اكتشف الطبي",
    "اسأل سينا",
    "مكالمة صوتية",
    "استشر طبيب عبر الهاتف",
    "محادثة نصية",
    "محادثة نصية",
    "دردش مع طبيب",
    "طبيب متوفر لمساعدتك",
    "ابدأ المكالمة الآن",
    "ابدأ المحادثة الآن",
    "تسجيل الدخول",
    "منتدى الطبي ماما",
    "شاركي تجاربك واستفيدي من تجارب الأمهات الأخريات",
    "الأكثر زيارة",
    "أسئلة وإجابات طبية",
    "أطباء متخصصين للإجابة على استفسار",
    "المقالات الطبية",
    "مقالات موثقة من الأطباء وفريق الطبي",
    "الفيديوهات الطبية",
    "فيديوهات للمعلومات والاكتشافات الطبية",
    "أكبر شبكة طبية في الوطن العربي",
    "الحاسبات الطبية",
    "اكتشف آخر الحاسبات الطبية",
    "الأوراق والأبحاث المنشورة",
    "أوراق وأبحاث منشورة من موقع الطبي",
    "اختبر نفسك",
    "اختبر نفسك مع الطبي",
    "نقبل تأمين التعاونية على الاستشارات الطبية",
    "حاسبة سعراتك الذكية",
    "سينا، مستشارك الصحي الموثوق",
    "تحدث مع سينا",
    "تطبيق الطبي",
    "أكبر تطبيق طبي عربي على الإنترنت!",
    "اكتشف المزيد",
    "رشاقتك تبدأ بخطوة!",
    "اكتشف أفضل",
    "الحميات لجسم مثالي",
    "إذا كان لديك سؤال يتعلق بنفس الموضوع",
    "تحدث مع طبيب",
    "المشاركة عبر وسائل التواصل الاجتماعي",
    "نسخ الرابط",
    "اقرأ أيضًا",
    "المصادر والمراجع",
    "تمت مراجعته من قِبل",
    "المؤلف",
    "ما الذي ترغبه مننا لتحسين المحتوى الطبي؟",
    "ارسال",
    "احصل على استشاره مجانيه, تواصل مع طبيب الان",
    "عرض كافة الأسئلة",
    "جميع الاخبار والمقالات",
    "لا يحتوي هذا المحتوى على إصدار باللغة الإنجليزية.",
    "هذا المحتوى لا يحتوي على النسخة العربية.",
    "Skip to content",
    "الرعاية في مايو كلينك",
    "الرعاية المتمحورة حول المرضى",
    "نبذة عن مايو كلينك",
    "احجز موعدًا طبيًا",
    "ابحث عن طبيب",
    "فروعنا",
    "التجارب السريرية",
    "تواصَل مع مجموعات دعم",
    "دليل المرضى والزوار",
    "التأمين والفواتير",
    "الأقسام والمراكز",
    "الخدمات الدولية",
    "تواصَل معنا",
    "دليل المرضى",
    "والزوار",
    "المكتبة الصحية",
    "الاختبارات والإجراءات",
    "كتب ونشرات مايو كلينك الصحية",
    "كتب ونشرات مايو كلينك",
    "للمهنيين الطبيين",
    "موارد للمهنيين الطبيين",
    "إحالة مريض",
    "التعليم الطبي المستمر",
    "اسأل خبراء مايو (AskMayoExpert)",
    "مختبرات مايو كلينك",
    "مركز الفيديو",
    "المجلات والمنشورات",
    "جمعية خريجي مايو كلينك",
    "التعليم الطبي",
    "الأبحاث والتعليم في مايو كلينك",
    "البحث العلمي",
    "الأبحاث في مايو كلينك",
    "الكادر البحثي",
    "المختبرات",
    "الـمَرافق الأساسية",
    "المراكز والبرامج",
    "الدوائر والأقسام",
    "التجارب السريرية",
    "مجلس المراجعة المؤسسية",
    "زمالات ما بعد الدكتوراه",
    "برامج المنح التدريبية",
    "كلية مايو كلينك للطب والعلوم",
    "كلية مايو كلينك للدراسات العليا في العلوم الطبية الحيوية",
    "كلية أليكس الطبية في مايو كلينك",
    "كلية مايو كلينك للدراسات الطبية العليا",
    "كلية مايو كلينك للعلوم الصحية",
    "كلية مايو كلينك للتطوير المهني المستمر",
    "كلية مايو كلينك للطب",
    "والعلوم",
    "التبرّع لمايو كلينك",
    "تبرَّع الآن",
    "التبرّع لمايو كلينك",
    "أسئلة متكررة",
    "اتصل بنا للتبرع",
    "الآن",
    "احجز موعدًا طبيًا",
    "تسجيل الدخول",
    "قائمة طعام",
    "احجز موعدًا طبيًا",
    "تبَرَّع",
    "ابحث عن طبيب",
    "الرعاية في مايو كلينك",
    "الرعاية المتمحورة حول المرضى",
    "نبذة عن مايو كلينك",
    "احجز موعدًا طبيًا",
    "ابحث عن طبيب",
    "فروعنا",
    "التجارب السريرية",
    "تواصَل مع مجموعات دعم",
    "دليل المرضى والزوار",
    "التأمين والفواتير",
    "الأقسام والمراكز",
    "الخدمات الدولية",
    "تواصَل معنا",
    "دليل المريض",
    "والزائر",
    "المكتبة الصحية",
    "الاختبارات والإجراءات",
    "نمط الحياة الصحي",
    "كتب ونشرات مايو كلينك الصحية",
    "كتب ونشرات مايو كلينك",
    "الصحية",
    "للمهنيين الطبيين",
    "موارد للمهنيين الطبيين",
    "إحالة مريض",
    "التعليم الطبي المستمر",
    "اسأل خبراء مايو (AskMayoExpert)",
    "مختبرات مايو كلينك",
    "مركز الفيديو",
    "المجلات والمنشورات",
    "جمعية خريجي مايو كلينك",
    "التعليم الطبي",
    "الأبحاث والتعليم في مايو كلينك",
    "البحث العلمي",
    "الأبحاث في مايو كلينك",
    "الكادر البحثي",
    "المختبرات",
    "الـمَرافق الأساسية",
    "المراكز والبرامج",
    "الدوائر والأقسام",
    "التجارب السريرية",
    "مجلس المراجعة المؤسسية",
    "زمالات ما بعد الدكتوراه",
    "برامج المنح التدريبية",
    "كلية مايو كلينك للطب والعلوم",
    "كلية مايو كلينك للدراسات العليا في العلوم الطبية الحيوية",
    "كلية أليكس الطبية في مايو كلينك",
    "كلية مايو كلينك للدراسات الطبية العليا",
    "كلية مايو كلينك للعلوم الصحية",
    "كلية مايو كلينك للتطوير المهني المستمر",
    "كلية الطب والعلوم في",
    "التبرّع لمايو كلينك",
    "تبرَّع الآن",
    "التبرّع لمايو كلينك",
    "أسئلة متكررة",
    "اتصل بنا للتبرع",
    "تبرَّع",
    "طلب موعد",
    "الآن",
    "طباعة",
    "قضايا صحَّة الأطفال",
        "هل تعلم",
        "اضطرابات الصحَّة النفسيَّة",
        "أيضًا انظر تقنيات العقل و الجسم",
        "يمكن للمصادر التالية باللغة الإنجليزية أن تكون مفيدة.يُرجى ملاحظة أن دليل MSD غير مسؤول عن محتوى هذه المصادر.",
        "احصل على التفاصيل الكاملة",
        "معلومات عن الأبحاث",
        "لمحة عامة عن الاضطرابات النفسية عند الأطفال",
        "المزيد حول أعراض الاضطراب.",
        "معهد أبحاث التوحد",
        "جمعية التوحد",
        "التوحد يتكلم",
        "الرابطة الوطنية للتوحد" ,
      "الحالات الطارئة",
        "الإصدار الخامس، مراجعة النص5",
        "يمكن للمصدر التالي ب الإنجليزية أن يكون مفيدًا يُرجى ملاحظة أن دليل غير مسؤول عن محتوى هذا المصادر.",
        "لمحة عامة عن",
        "نورد فيما يلي مصدرًا باللغة الإنجليزية قد يكون مفيدًا.يُرجى ملاحظة أن دليل MSD غير مسؤول عن محتوى هذا المصدر.",
        "اجعل صحتك النفسية أولوية وتحدث مع أخصائي نفسي",
        "الحمل والولادة",
        "رحلة الحمل خطوة بخطوة",
        "تابعي تفاصيل رحلة حملك وتطورات جنينك",
        "موسوعة الأدوية",
        "معلومات مفصلة عن الأدوية والعلاجات",
        "الدليل الطبي",
        "الأخبار الطبية",
        "آخر الأخبار الطبية",
     "معلومات عن الفحوصات والتحاليل الطبية",
        "قدر وجباتك واحتياجاتك الغذائية على الفور",
        "منتدى الطبي ماما",
        "أسئلة وإجابات مجانية مقترحة متعلقة بأمراض الأطفال",
        "أسئلة وإجابات مجانية مقترحة متعلقة",
        "عندما اخرج من بيتي فأني احس اني سأتقيأ بشدة ولا اتقيأ فقط خارج البيت وهذه الحالة دامت لشهر وللأن",
        "فراش ذكي لمرضى الصرع",
        "آلام العضلات المزمن",
        "مرض المرازمس او السغل او الضوى",
        "سعال ديكي",
        "دفتيريا كاذبة",
        "التهاب الشفة الزاوي",
        "ضمور ضخامي كاذب",
        "متلازمة آبير",
     "احصل على تقدير استهلاكك اليومي من الطعام واتخذ خيارات أكثر صحة. جربه الآن",
        "التقط صورة سريعة لوجبتك واكتشف محتواها من السعرات الحرارية بسهولة.",
        "احسب الآن",
        "مصطلحات طبية مرتبطة بأمراض الأطفال",
        "متلازمة ما بعد كورونا لدى الأطفال",
        "متلازمة أسبرجر",
        "متلازمة الطفل المرن وتأثيرها في عضلات الأطفال",
        "البواسير عند الأطفال",
        "جرثومة المعدة عند الاطفال",
        "القولون العصبي عند الاطفال",
        "التقزم (تأخر النمو)",
        "الامساك عند الرضع",
        "يرقان حليب الثدي",
        "الفشل الكلوي عند الاطفال",
        "الفتق الحجابي عند الاطفال",
        "تطبل البطن عند الأطفال",
        "تضخم القلب عند الأطفال",
     "الورم الدموي تحت الشبكي",
        "كزاز المواليد االجدد",
        "اجهاد عضلي لدى الاطفال",
        "سمنة الاطفال",
        "سرطان الاطفال",
        "التهاب الجيوب الانفية عند الأطفال",
        "تليف كيسي طفلي",
        "الداء الخامس ( الحمامى العدوائية)",
        "متلازمة فرط الحركة",
        "متلازمة تورش",
        "متلازمة الحبل النطاقي",
        "متلازمة الجنين الكحولي",
        "فرط التعظم القشري عند الرضيع",
        "داء مضخم للخلايا الاشتمالية",
        "داء مشتملي",
        "داء ليترر سيوي",
      "داء كاواساكي",
        "داء كافي",
        "داء سيلتر",
        "داء فير",
        "داء سويفت",
        "داء الاحمرار",
        "اعتلال الأعصاب المحمر الموذم",
        "التهاب الاعصاب الجلدية",
        "فتق بوكدالك",
        "طفح كابوزي حماقي الشكل",
        "طفح ظاهر فجائي",
        "وباء الطفح الوردي",
        "الصفار عند المواليد او يرقان الرضع",
        "متلازمة داون",
        "متلازمة ايزنمنغر",
        "ضمور عضلي نخاعي",
        "الخناق (الدفتيريا)",
       "خانوق غشائي",
        "خانوق كاذب",
        "خانوق دفتيري",
        "الخانوق",
        "الحصبة الالمانية",
        "الحصبة",
        "تلين العظام الطفلي",
        "تلين الحنجرة",
        "التهاب الجلد الحفاظي",
        "قيلة مائية وراثية",
        "اختناق ثانوي",
        "أدوية لعلاج الأمراض المرتبطة بأمراض الأطفال",
        "زنكو بيبي",
        "زينيكس",
        "بيلينورم",
        "جديد الطبي",
     "سينا، مستشارك الصحي الموثوق",
        "حول التطورات الجديدة في مجال العلاجات والتدخلات الطبية والاختبارات المستخدمة للوقاية من هذه الحالة الصحية وعلاجها وإدارتها.",
        "استكشِف دراسات",
        "نمط الحياة والعلاجات المنزلية",
        "طب وصحة",
        "تكنولوجيا",
        "التطور المهني",
        "المال والأعمال",
        "الإسلام",
        "إقرأ أيضاً",
        "يمنع نقل هذا المقال كما هو أو استخدامه في أي مكان آخر تحت طائلة المساءلة القانونية، ويمكن استخدام فقرات أو أجزاء منه بعد الحصول على موافقة رسمية من",
        "منتدى المدربين المحترفين",
        "أنماط الشخصيَّة التسعة التي حدَّدها علماء النفس",
        "دليلك الموثوق لتطوير نفسك والنجاح في تحقيق أهدافك.",
     "معلومات عامة عن العديد من جوانب اضطراب القلق الاجتماعي، بما في ذلك إحصائيات الانتشار",
        "منظمة كبيرة غير ربحية توفر إمكانية الوصول إلى أدوات التحرِّي على الإنترنت، وخط هاتفي للمساعدة، ومنتديات، وعدد من مجموعات الدعم (بعضها افتراضي)",
        "الرابطة الوطنية للقهام العصبي والاضطرابات المرافقة",
        "رعاية المريض والمعلومات الصحية",
    "النشرة الإخبارية: خطاب مايو كلينك الصحي — النسخة الرقمية",
    "كتاب مايو كلينك عن صحة الأسرة",
    "أظهر المزيد من منتجات Mayo Clinic",
    "ذات صلة",
    "إظهار المَراجع",
    "الإجراءات الطبية ذات الصلة",
    "لا تُقدم Mayo Clinic الدعم للشركات أو المنتجات المُعلَّن عنها هنا. لكن تدعم العائدات الإعلانية رسالتنا غير الربحية.",
    "الإعلان والرعاية",
    "البوليصة",
    "فرص الإعلان",
    "خيارات الإعلان",
    "تحقق من هذه الكتب الأكثر مبيعًا والعروض الخاصة على الكتب والنشرات الإخبارية من",
    "عطاؤك له أثر كبير — تبرَّع الآن!",
    "تساهم التبرّعات، وهي قابلة للخصم الضريبي، في دعم آخر التطورات في الأبحاث وطرق الرعاية لإحداث نقلة نوعية في الطب.",
    "نبذة عن هذا الموقع",
    "تواصَل معنا",
    "فروعنا",
    "سياسة المعلومات الصحية",
    "منظمة رعاية مسؤولة (ACO) معتمَدة لدى ميديكير",
    "الطلبات الإعلامية",
    "الشبكة الإخبارية",
    "شفافية الأسعار",
    "المهنيون",
    "الطبيون",
    "اسأل خبراء مايو (AskMayoExpert)",
    "التجارب السريرية",
    "جمعية خريجي مايو كلينك",
    "البرنامج الصحي للمسؤولين الإداريين",
    "الشراكات المهنية الدولية",
    "المَرافق والعقارات",
    "معلومات المورّدين",
    "المهنيون",
    "الطبيون",
    "سياسة الخصوصية",
    "إشعار ممارسات الخصوصية",
    "إشعار بعدم التمييز",
    "بيان حول تسهيلات إتاحة محتوى الموقع لذوي الإعاقة",
    "سياسة الإعلانات والرعاية",
    "خريطة الموقع",
    "إدارة ملفات الارتباط",
    "الشروط والأحكام",
    "سياسة الخصوصية",
    "إشعار ممارسات الخصوصية",
    "إشعار بعدم التمييز",
    "بيان حول تسهيلات إتاحة محتوى الموقع لذوي الإعاقة",
    "سياسة الإعلانات والرعاية",
    "خريطة الموقع",
    "إدارة ملفات الارتباط",
    "اللغة",
    "© 1998-2025 مؤسسة مايو للتعليم والبحث الطبي. جميع الحقوق محفوظة.",
    "العربية",
    "تصفح مجالات النجاح",
    "مهارات النجاح",
    "حفظ المقال",
    "نسخ إلى الحافظة",
    "فهرس",
    "موقع النجاح نت",
    "أضف تعليقاً",
    "يمنع نقل هذا المقال كما هو أو استخدامه في أي مكان آخر تحت طائلة المساءلة القانونية، ويمكن استخدام فقرات أو أجزاء منه بعد الحصول على موافقة رسمية من",
    "الموافقة على إنشاء حساب للتفاعل في النجاح نت",
    "نشر",
    "اشترك بالنشرة الدورية",
    "اشترك",
    "مقالات مرتبطة",
    "تدريب المدربين",
    "بوابة مدربو إيلاف ترين",
    "إيلاف ترين",
    "مركز دبي للتعلم السريع",
    "النجاح نت",
    "أحدث المقالات",
    "> مهارات النجاح",
    "> المال والأعمال",
    "> اسلوب حياة",
    "> التطور المهني",
    "> طب وصحة",
    "> الأسرة والمجتمع",
    "> فيديو",
    "> الاستشارات",
    "> الخبراء",
    "> الكتَاب",
    "> أدوات النجاح نت",
    "مشاريع النجاح نت",
    "> منحة غيّر",
    "خدمات وتواصل",
    "> أعلن معنا",
    "> النجاح بارتنر",
    "> اشترك في بذور النجاح",
    "> التسجيل في النجاح نت",
    "> الدخول إلى حسابي",
    "> الاتصال بنا",
    "النجاح نت دليلك الموثوق لتطوير نفسك والنجاح في تحقيق أهدافك.",
    "نرحب بانضمامك إلى فريق النجاح نت.",
    "ننتظر تواصلك معنا.",
    "للخدمات الإعلانية يمكنكم الكتابة لنا",
    "حولنا",
    "سياسة الخصوصية",
    "سياسة الاستخدام",
    "أسرار المال",
    "مايو كلينك عن صحة الأسرة",
    "أظهر المزيد من منتجات وخدمات Mayo Clinic",
    "من إعداد فريق مايو كلينك",
    "طلب تحديد موعد",
    "الطلاب",
    "متطلبات القبول",
    "البرامج الدراسية",
    "منصة الطلاب والهيئة التدريسية",
    "الحياة الصحية",
    "الصفحة الرئيسية",
    "موضوعات صحية",
    "انظر أيضًا",
    "الباحثون",
    "المرضى",
    "الدوليون",
    "المواعيد الطبية",
     "الخدمات المالية",
    "الفروع والمكاتب الدولية",
    "الرعاية الخيرية والمساعدة",
    "المالية",
    "تقييم الاحتياجات المجتمعية",
    "مستندات المساعدة المالية – أريزونا",
    "مستندات المساعدة المالية – فلوريدا",
    "مستندات المساعدة المالية – مينيسوتا",
    "تابعنا على منصات التواصل",
     "والشركات التابعة لها. جميع الحقوق محفوظة.",
    "النسخة الخامسة",
    "المراجع نصيًا",
    "حقائق سريعة",
    "استكشف الوظائف",
    "في الات الإلكترونية المجانية",
    "نبذة عن مايو",
    "كلينك",
    "رابط المقال",
    "أحدث",
    "عرض كل",
    "آخر مقاطع الفيديو من أطباء متخصصين",
    "مقالات",
    "محتوى طبي موثوق من أطباء وفريق الطبي",

    "منتدى الطبي ماما",
    "الأسئلة",
    "أخبار طبية",
    "المختبرات",
    "شبكة طبية",
    "الصحة الجنسية",
    "صحة المرأة",
    "صحة الرجل",
    "أمراض نسائية",
     "أمراض المسالك البولية والتناسلية",
    "مصطلحات طبية",
    "اختبر نفسك مع الطبي",
    "المشاركة عبر وسائل التواصل الاجتماعي",
    "اقرأ أيضًا",
    "للمزيد",
    "تمت مراجعته من قِبل",
    "احصل على استشاره مجانيه",
    "عرض كافة الأسئلة",
    "احسب الآن",
    "doi:10.7326/AITC202208160", "Nov. 16, 2022", "Dec. 1, 2022", "Nov. 16, 2022", "doi:10.7326/AITC202208160", ". 2020; doi:10.1016/B978-0-444-64123-6.00026-6", "2020; doi:10.1111/imj.14691", ". 2020; doi:10.1016/S0140-6736(20)30059-3",
    "March 17, 2023", "2018; doi:10.1016/j.jad.2017.10.034", "April 15, 2023",
    "تسجيل الدخول", "متابعة بحساب جوجل", "متابعة بحساب فيسبوك", "إنشاء حساب",
    "الرعاية في مايو كلينك", "احجز موعدًا طبيًا", "ابحث عن طبيب", "فروعنا", "التأمين والفواتير",
    "الخدمات الدولية", "كتب ونشرات مايو كلينك", "اسأل خبراء مايو", "مختبرات مايو كلينك",
    "مجلس المراجعة المؤسسية", "زمالات ما بعد الدكتوراه", "كلية مايو كلينك", "تبرَّع الآن",
    "طلب موعد", "طباعة", "فريق مايو كلينك", "النشرة الإخبارية", "منتجات وخدمات Mayo Clinic",
    "الإعلان والرعاية", "فرص الإعلان", "خيارات الإعلان",
    "طبيبك معك أينما كنت...", "تحدث مع طبيب الآن!", "أطباء متوفرون لمساعدتك",
    "اكتشف الطبي",  "طبيب متوفر لمساعدتك", "استشر طبيب عبر الهاتف",
    "شاركي تجاربك واستفيدي من تجارب الأمهات الأخريات", "أكبر شبكة طبية في الوطن العربي",
    "الحاسبات الطبية", "أوراق وأبحاث منشورة من موقع الطبي", "موسوعة للمصطلحات الطبية والمعلومات",
    "نقبل تأمين التعاونية على الاستشارات الطبية", "رشاقتك تبدأ بخطوة!",
    "اكتشف أفضل الحميات لجسم مثالي", "رفيقك في رحلة الحمل والأمومة!", "اكتشفي المزيد",
    "عمليات البحث الأخيرة", "المواضيع الشائعة", "...", "نسخ الرابط", "سؤال من",
    "أمراض الأطفال", "ما الذي ترغبه منا لتحسين المحتوى الطبي؟", "ارسال",
    "هل وجدت هذا المحتوى الطبي مفيدا؟", "طاقم الطبي", "المؤلف", "لكن تدعم العائدات الإعلانية رسالتنا غير الربحية"
    "عندما اخرج من بيتي فأني احس اني سأتقيأ بشدة ولا اتقيأ فقط خارج البيت وهذه الحالة دامت لشهر وللأن",
    "تحويل السؤال للطب الباطني نظرا للعمر", "محتوى طبي موثوق من أطباء وفريق الطبي",
    "جميع الاخبار والمقالات", "آخر مقاطع الفيديو من أطباء متخصصين", "أحدث الفيديوهات الطبية",
    "عرض كل الفيديوهات الطبية", "أنشطة ممتعة يجب على الأزواج القيام بها معًا",
    "نصائح للعودة إلى المدارس", "آخر مستجدات فيروس كورونا الجديد اليوم (22 آذار)",
    "احصل على تقدير استهلاكك اليومي من الطعام واتخذ خيارات أكثر صحة. جربه الآن",
    "التقط صورة سريعة لوجبتك واكتشف محتواها من السعرات الحرارية بسهولة.",
    "ابحث عن معلوماتك الطبية بطريقة جديدة كما لم تعهد من قبل باستخدام الذكاء الاصطناعي مع سينا",
    "للمتابعة، قم بتسجيل الدخول", "أقر بأنني قرأت وفهمت", "شروط الخصوصية وسياسة الإستخدام",
    "الرعاية المتمحورة حول المرضى", "نبذة عن مايو كلينك", "التجارب السريرية",
    "تواصَل مع مجموعات دعم", "المكتبة الصحية", "الاختبارات والإجراءات",
    "موارد للمهنيين الطبيين", "مركز الفيديو", "المجلات والمنشورات", "جمعية خريجي مايو كلينك",
    "التعليم الطبي المستمر", "الأبحاث والتعليم في مايو كلينك", "الكادر البحثي",
    "الـمَرافق الأساسية", "المراكز والبرامج", "الدوائر والأقسام", "برامج المنح التدريبية",
    "كلية مايو كلينك للطب والعلوم", "كلية مايو كلينك للدراسات العليا في العلوم الطبية الحيوية",
    "كلية أليكس الطبية في مايو كلينك", "كلية مايو كلينك للدراسات الطبية العليا",
    "كلية مايو كلينك للعلوم الصحية", "كلية مايو كلينك للتطوير المهني المستمر",
    "أسئلة متكررة", "اتصل بنا للتبرع", "قائمة طعام", "الرعاية في مايو كلينك",
    "من إعداد فريق مايو كلينك", "النشرة الإخبارية: خطاب مايو كلينك الصحي — النسخة الرقمية",
    "كتاب مايو كلينك عن صحة الأسرة", "لا تُقدم Mayo Clinic الدعم للشركات أو المنتجات المُعلَّن عنها هنا",
    "البوليصة", "تحقق من هذه الكتب الأكثر مبيعًا والعروض الخاصة على الكتب والنشرات الإخبارية من",
    "عطاؤك له أثر كبير — تبرَّع الآن!", "استكشف الوظائف", "اشترك في النشرات الإلكترونية المجانية",
    "سياسة المعلومات الصحية", "منظمة رعاية مسؤولة (ACO) معتمَدة لدى ميديكير",
    "الطلبات الإعلامية", "الشبكة الإخبارية", "شفافية الأسعار",
    "محفوظة لشركة Merck & Co., Inc., Rahway, NJ, USA والشركات التابعة لها. جميع الحقوق محفوظة.",
    "البرنامج الصحي للمسؤولين الإداريين", "الشراكات المهنية الدولية", "المَرافق والعقارات",
    "معلومات المورّدين", "متطلبات القبول", "البرامج الدراسية", "منصة الطلاب والهيئة التدريسية",
    "الدوليون", "الخدمات المالية", "الفروع والمكاتب الدولية", "تقييم الاحتياجات الصحية المجتمعية",
    "مستندات المساعدة المالية – أريزونا", "مستندات المساعدة المالية – فلوريدا",
    "مستندات المساعدة المالية – مينيسوتا", "تابعنا على منصات التواصل", "احصل على تطبيق مايو كلينك",
    "إشعار ممارسات الخصوصية", "إشعار بعدم التمييز",
    "بيان حول تسهيلات إتاحة محتوى الموقع لذوي الإعاقة", "خريطة الموقع", "إدارة ملفات الارتباط",
    "اللغة: العربية", "© 1998-2025 مؤسسة مايو للتعليم والبحث الطبي. جميع الحقوق محفوظة.",
    "إظهار المَراجع", "المنتجات والخدمات", "أسرار المال", "آخر تحديث:",
    "حفظ المقال", "هيئة التحرير", "فهرس +", "المصدر +", "تنويه:",
    "يمنع نقل هذا المقال كما هو أو استخدامه في أي مكان آخر تحت طائلة المساءلة القانونية",
    "إدارة موقع النجاح نت", "الموافقة على إنشاء حساب للتفاعل في النجاح نت", "مقالات مرتبطة",
    "نشر ..", "مواقعنا", "إيلاف ترين", "تدريب المدربين", "مركز دبي للتعلم السريع",
    "عضوية المدرب المعتمد ICTM", "موسوعة التعليم والتدريب", "أحدث المقالات", "فيديو",
    "الاستشارات", "الخبراء", "الكتَاب", "أدوات النجاح نت", "مشاريع النجاح نت", "منحة غيّر",
    "خدمات وتواصل", "أعلن معنا", "النجاح بارتنر", "اشترك في بذور النجاح", "الاتصال بنا",
    "النجاح نت دليلك الموثوق  نفسك والنجاح في تحقيق أهدافك.",
    "نرحب بانضمامك إلى فريق النجاح نت. ننتظر تواصلك معنا.",
    "للخدمات الإعلانية يمكنكم الكتابة لنا", "الدخول", "التسجيل", "حولنا", "سياسة الخصوصية",
    "سياسة الاستخدام", "منتدى المدرينب المحتلتطويررفين", "بوابة مدربو إيلاف ترين", "اشترك نشر","والشركات التابعة لها. جميع الحقوق محفوظة."
    "أضف تعليقاً", "رابط المقال","إصدار المُستخدِم","محرّم 1445","والشركات التابعة لها. جميع الحقوق محفوظة",
    "التصاريح","ربيع الأول","الشروط والأحكام","سياسة ","إشعار ممارسات ","بيان  تسهيلات إتاحة محتوى الموقع لذوي الإعاقة",
    "سياسة الإعلانات والرعاية","الشروط والأحكام","إشعار ممارسات","(مايو كلينك)","اشترك  بذور النجاح","النجاح نت","إلى حسابي",
    " النجاح نت دليلك الموثوق لتطوير نفسك والنجاح  تحقيق أهدافك","نرحب بانضمامك إلى فريق النجاح نت","ننتظر تواصلك معنا","المعدل",
    "قانون  الولايات المتحدة يضمن حقوقًا معينة للأشخاص ذوي الإعاقة","قانون  الولايات المتحدة يحظر التمييز على أساس الإعاقة",
    "20319016", "20166452", "20155318", "20373903", "20373903",
    "20228119", "20228119", "20319029", "20228096", "20228096",
    "20197160", "20179259", "20228125", "2022818",
    "14616734..1499207.", "01..0000554615.", "92598.",
    "10....02.", "10....08.", "10....04.", "012."
    ]


    arabic_months = [
        "محرم", "صفر", "ربيع الأول", "ربيع الثاني",
        "جمادى الأولى", "جمادى الآخرة", "رجب",
        "شعبان", "رمضان", "شوال", "ذو القعدة", "ذو الحجة"
    ]

    english_months = [
        "يناير", "فبراير", "أبريل", "مايو", "يونيو",
        "يوليو", "أغسطس", "سبتمبر", "أكتوبر", "نوفمبر", "ديسمبر"
    ]

    arabic_months_str = "|".join(arabic_months)
    english_months_str = "|".join(english_months)
    all_months_str = f"{arabic_months_str}|{english_months_str}"

    date_patterns = [
        r"\d{1,2}/\d{1,2}/\d{2,4}",
        r"\d{1,2}-\d{1,2}-\d{2,4}",
        fr"\d{{1,2}}\s+(?:{all_months_str})\s+\d{{2,4}}",
        fr"(?:{arabic_months_str}|{english_months_str})\s+\d{{1,2}},\s+\d{{2,4}}"
    ]


    phrases_pattern = '|'.join([re.escape(phrase) for phrase in irrelevant_phrases])
    months_pattern = '|'.join(arabic_months + english_months)
    dates_pattern = '|'.join(date_patterns)



    combined_pattern = f"{phrases_pattern}|{months_pattern}|{dates_pattern}"


    cleaned_text = re.sub(combined_pattern, '', text_content)


    cleaned_text = re.sub(r"\b\d{1,2}[\/-]\d{1,2}\b", '', cleaned_text)


    with open(output_file, 'w', encoding='utf-8') as file:
        file.write(cleaned_text)

    print(f"Cleaned text saved to: {output_file}")


clean_text_file('/content/rData.txt', '/content/cleaned_rData.txt')
# Out:
# Cleaned text saved to: /content/cleaned_rData.txt

# %%
import re

def remove_all_years(input_file, output_file):

    with open(input_file, 'r', encoding='utf-8') as f:
        text = f.read()

    # Pattern for Gregorian years (1900-2099)
    gregorian_pattern = r'\b(19|20)\d{2}\b'

    # Pattern for Hijri years (1000-1500 AH)
    hijri_pattern = r'\b(1[0-4]\d{2}|1500)\b'

    year_pattern = re.compile(f'{gregorian_pattern}|{hijri_pattern}')

    cleaned_text = year_pattern.sub('', text)

    with open(output_file, 'w', encoding='utf-8') as f:
        f.write(cleaned_text)

    print(f" All years removed. Saved to: {output_file}")


remove_all_years('/content/cleaned_rData.txt', '/content/no_years_rData.txt')
# Out:
#  All years removed. Saved to: /content/no_years_rData.txt

# %%
import re

def remove_all_web_references(input_file, output_file):
    with open(input_file, 'r', encoding='utf-8') as file:
        text_content = file.read()


    web_pattern = re.compile(
        r'(?:https?://|www\.)[^\s]+'  # URLs
        r'|[\w\.-]+@[\w\.-]+'         # Emails
        r'|@[^\s]+'                    # Social handles
        r'|#\w+'                       # Hashtags
    )

    cleaned_text = web_pattern.sub('', text_content)

    with open(output_file, 'w', encoding='utf-8') as file:
        file.write(cleaned_text)

    print(f"All web references removed. Saved to: {output_file}")


remove_all_web_references('/content/no_years_rData.txt', '/content/noLinks_cleaned_rData.txt')
# Out:
# All web references removed. Saved to: /content/noLinks_cleaned_rData.txt

# %%
import re

def remove_non_arabic(input_file, output_file):
    with open(input_file, 'r', encoding='utf-8') as f:
        text = f.read()

    # Remove non-Arabic words
    arabic_only = re.sub(r'[^\u0600-\u06FF\u0750-\u077F\u08A0-\u08FF\uFB50-\uFDFF\uFE70-\uFEFF\s،؛؟.!0-9]', '', text)

    with open(output_file, 'w', encoding='utf-8') as f:
        f.write(arabic_only)

    print(f"Done! Cleaned file saved as {output_file}")

remove_non_arabic('noLinks_cleaned_rData.txt', 'arabic_only_rData.txt')
# Out:
# Done! Cleaned file saved as arabic_only_rData.txt

# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.51.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.30.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (2025.3.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (4.13.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.1.31)

# %%
from transformers import AutoTokenizer
import re

def arabert_tokenizer(input_file, output_file):
    # Load AraBERT tokenizer
    tokenizer = AutoTokenizer.from_pretrained("aubmindlab/bert-base-arabertv02")

    with open(input_file, 'r', encoding='utf-8') as f:
        text = f.read()

    # Step 1: Create a regex pattern to match all protected words
    protected_words = [
        'وجود', 'واضح', 'النمو', 'نمو', 'ينمو', 'يُدعنها', 'وفاة', 'وراثة',
        'وسائل', 'او', 'نحو', 'وجد', 'وقت', 'يبدو', 'واحدةٍ', 'هو', 'وزناً',
        'وزن', 'ما', 'وضوحاً', 'وجهة', 'واحد', 'وضع', 'وزنهم', 'وصف', 'وفقًا',
        'الموادية', '0.5٪', '1.9٪', '3.1٪', 'وصفات', 'وباء', 'وفاتي', 'لو',
        'وقعت', 'وصفة', 'وضعها', 'واجهها', 'وصول', 'وصمة', 'وراثيًا', 'وحيدين',
        'تبدو', 'واجباتهم', 'وسط', 'وصفها', 'ولادة', 'وُلد', 'وثيقة', 'وجبة',
        'وصولهم', 'وقوع', 'درو', 'ورد', 'وجوده', 'واضحة', 'واسع', 'وجه', 'وراثي',
        'ذوو', 'وجيزة.', 'ومضات', 'وشيك', 'وحدة', 'واقعيين', 'واقعيَّة', 'واعد',
        'واسعة', 'وجبات', 'وقوع', 'وضوحًا', 'وُضِعت', 'وسيلة', 'وقتًا', 'واحدًا',
        'وثيقة', 'شديدو', 'واثقين', 'ولاء', 'وعيًا', 'الربو', 'النمو', 'وخيمة',
        'بشهو', 'واخزة', 'وَعيهم', 'وعي', 'وجيزة', 'وعيه', 'واعٍ', 'وقتيّ', 'يعزو',
        'وجودهم', 'والديه', 'فالجو', 'وراء', 'وسائل', 'ورم', 'واضحاً', 'بالفديو',
        'وراءه،', 'وجهات', 'واسع', 'وراثية،', 'فهو', 'ذو', 'وقائية', 'يدعو',
        'وحيد،', 'وجبة', 'اللاثنائية', 'وظيفي', 'واثقة', 'واقعها،', 'وجد',
        'وضعها', 'وضع', 'واجهت', 'وهمية', 'وحيداً', 'وظائف', 'واقعه', 'واقعها،',
        'وعيك', 'واقعية', 'النفسيّة', 'ورق', 'البيرو', 'أو', 'وحده', 'حول', 'جو',  'هُو',  'وُجود',
        'وُجِد', 'وظيفة', 'ولادته', 'واثق','والدته','وجوه', 'وفقاً','واقعيَّة','وسواس','نحو','اختصاصيو','مقدِّمو'
    ]

    # Step 2: Add special cases that need separation
    separation_rules = [
        (r'(ملحوظاً)\.(قد)', r'\1 \2'),
        (r'(عادةً)\.(قد)', r'\1 \2'),
        (r'(عادةً)\.(في)', r'\1 \2'),
        (r'(الخفيف)(يتميز)', r'\1 \2'),
        (r'(شديدٍ)(يحتاج)', r'\1 \2'),
        (r'(كبيرٍ)\.(في)', r'\1 \2'),
        (r'(دقيقٍ)\.(يجري)', r'\1 \2'),
        (r'(بتحدٍّ)\.(ينبغي)', r'\1 \2'),
        (r'(أقلّ)\.(قدمت)', r'\1 \2'),
        (r'(عادةً)\.(في)', r'\1 \2'),
        (r'(مؤخراً)\.(يضع)', r'\1 \2'),
        (r'(ضوحاً)\.(قَد)', r'\1 \2'),
        (r'(العائليّ)،(كما)', r'\1 \2'),
        (r'(كاملٍ)\.(على)', r'\1 \2'),
        (r'(الانتحار)(عندَ)', r'\1 \2'),
        (r'(الجنسية)(الجندرية)', r'\1 \2'),
        (r'(عادةً)\.(يقوم)', r'\1 \2'),
        (r'(صعوبةً)\.(إذا)', r'\1 \2'),
        (r'(الأزقة)(انظر)', r'\1 \2'),
        (r'(الانتباه)(فرط)', r'\1 \2'),
        (r'(لغوي)(كلامي)', r'\1 \2'),
        (r'(تضرراً)\.(عادةً)', r'\1 \2'),
        (r'(الشخصيَّة)(تبدُّد)', r'\1 \2'),
        (r'(الشخصية)(الغُربَة)', r'\1 \2'),
        (r'(العلاجَ)\.(كما)', r'\1 \2'),
        (r'(الحَدِّيّ)\.(من)', r'\1 \2'),
        (r'(الحديّ)\.(تعرَّض)', r'\1 \2'),
        (r'(أطفالاً)\.(يُسهم)', r'\1 \2'),
        (r'(عادةً)؛(فعلى)', r'\1 \2'),
        (r'(الحَدِّيّ)(يمكن)', r'\1 \2'),
        (r'(بشراسة)؛(أو)', r'\1 \2'),
        (r'(تائهون)(أو)', r'\1 \2'),
        (r'(تاهو)(الفترةً)', r'\1 \2'),
        (r'(النهم)(الشراهة)', r'\1 \2'),
        (r'(عادةً)\.(بالنسبة)', r'\1 \2'),
        (r'(العصبيّ)،(حيث)', r'\1 \2'),
        (r'(فعليّ)\.(إذا)', r'\1 \2'),
        (r'(أو)(فقدان)', r'\1 \2'),
        (r'(تجنّب)(تقييد)', r'\1 \2'),
        (r'(التجنُّبي)(التقييدي)', r'\1 \2'),
        (r'(المُتجنِّب)(المُقيد)', r'\1 \2'),
        (r'(العرَّات)\.(أو)', r'\1 \2'),
        (r'(ضائقة)(ضعف)', r'\1 \2'),
        (r'(مستوي)(التاكد)', r'\1 \2'),
        (r'(توجد)(فيه)', r'\1 \2'),
        (r'(زوايا)(يقف)', r'\1 \2'),
        (r'(الواصل)(من)', r'\1 \2'),
        (r'(الخارجيه)(تنزع)', r'\1 \2'),
        (r'(الراس)(يضغط)', r'\1 \2'),
        (r'(العمل)؛(أو)', r'\1 \2'),
        (r'(متى)\؟(من)', r'\1 \2'),
        (r'(قليلاً)؛(فعلى)', r'\1 \2'),
        (r'(أفكار)(المُعتدي)', r'\1 \2'),
        (r'(النفس)(جرح)', r'\1 \2'),
        (r'(بالاكتئاب)\.(يبدو)', r'\1 \2'),
        (r'(السبب)\.(وجد)', r'\1 \2'),
        (r'(الاكتِئاب)(بعد)', r'\1 \2'),
        (r'(ما)\.(يُصيبُ)', r'\1 \2'),
        (r'(وفاتي)\.(قد)', r'\1 \2'),
        (r'(وصفها)\.(تتمتع)', r'\1 \2'),
        (r'(وجبة)\.(غالبًا)', r'\1 \2'),
        (r'(جداً)\.(فعلى)', r'\1 \2'),
        (r'(عالٍ)\.(على)', r'\1 \2'),
        (r'(وجيزة)\.(على)', r'\1 \2'),
        (r'(ما)\.(غالبًا)', r'\1 \2'),
        (r'(الشخصية)(تبدُّد)', r'\1 \2'),
        (r'(ما)؛(فعلى)', r'\1 \2'),
        (r'(النمط)(تُخفِّف)', r'\1 \2'),
        (r'(عادةً)،(فعلى)', r'\1 \2'),
        (r'(بدنيةً)،(حيث)', r'\1 \2'),
        (r'(وعيه)\.(قد)', r'\1 \2'),
        (r'(وجيزة)\.(بعد)', r'\1 \2'),
        (r'(التوافق)(الرضا)', r'\1 \2'),
        (r'(الآخر)\.(وردًا)', r'\1 \2'),
        (r'(كَثافَتها)(وقد)', r'\1 \2'),
        (r'(مقدار)(الطعام)', r'\1 \2'),
        (r'(أمر)(شائع)', r'\1 \2'),
        (r'(تجنب)(تقييد)', r'\1 \2')
    ]

    # Create a regex pattern that matches all protected words
    protected_pattern = re.compile(
        r'(?:' + '|'.join(map(re.escape, sorted(protected_words, key=len, reverse=True))) + r')'
    )

    # Step 3: Apply separation rules before protection
    for pattern, replacement in separation_rules:
        text = re.sub(pattern, replacement, text)

    # Step 4: Split the text into protected and non-protected segments
    segments = []
    last_end = 0
    for match in protected_pattern.finditer(text):
        # Add the text before the match
        segments.append((text[last_end:match.start()], False))
        # Add the protected match
        segments.append((match.group(), True))
        last_end = match.end()
    # Add remaining text
    segments.append((text[last_end:], False))

    # Step 5: Process each segment
    tokens = []
    for segment, is_protected in segments:
        if is_protected:
            tokens.append(segment)
        else:
            # Tokenize non-protected segments with AraBERT
            segment_tokens = tokenizer.tokenize(segment)
            tokens.extend(segment_tokens)

    # Write tokens to output file
    with open(output_file, 'w', encoding='utf-8') as f:
        f.write("\n".join(tokens))

arabert_tokenizer("arabic_only_rData.txt", "data_tokensBert.txt")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/381 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/384 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/825k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.64M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]

# %%
import re

def unified_arabic_tokenizer(input_file, output_file):
    with open(input_file, 'r', encoding='utf-8') as f:
        text = f.read()

    # Step 1: Create a regex pattern to match all protected words
    protected_words = [
        'وجود', 'واضح', 'النمو', 'نمو', 'ينمو', 'يُدعنها', 'وفاة', 'وراثة',
        'وسائل', 'او', 'نحو', 'وجد', 'وقت', 'يبدو', 'واحدةٍ', 'هو', 'وزناً',
        'وزن', 'ما', 'وضوحاً', 'وجهة', 'واحد', 'وضع', 'وزنهم', 'وصف', 'وفقًا',
        'الموادية', '0.5٪', '1.9٪', '3.1٪', 'وصفات', 'وباء', 'وفاتي', 'لو',
        'وقعت', 'وصفة', 'وضعها', 'واجهها', 'وصول', 'وصمة', 'وراثيًا', 'وحيدين',
        'تبدو', 'واجباتهم', 'وسط', 'وصفها', 'ولادة', 'وُلد', 'وثيقة', 'وجبة',
        'وصولهم', 'وقوع', 'درو', 'ورد', 'وجوده', 'واضحة', 'واسع', 'وجه', 'وراثي',
        'ذوو', 'وجيزة.', 'ومضات', 'وشيك', 'وحدة', 'واقعيين', 'واقعيَّة', 'واعد',
        'واسعة', 'وجبات', 'وقوع', 'وضوحًا', 'وُضِعت', 'وسيلة', 'وقتًا', 'واحدًا',
        'وثيقة', 'شديدو', 'واثقين', 'ولاء', 'وعيًا', 'الربو', 'النمو', 'وخيمة',
        'بشهو', 'واخزة', 'وَعيهم', 'وعي', 'وجيزة', 'وعيه', 'واعٍ', 'وقتيّ', 'يعزو',
        'وجودهم', 'والديه', 'فالجو', 'وراء', 'وسائل', 'ورم', 'واضحاً', 'بالفديو',
        'وراءه،', 'وجهات', 'واسع', 'وراثية،', 'فهو', 'ذو', 'وقائية', 'يدعو',
        'وحيد،', 'وجبة', 'اللاثنائية', 'وظيفي', 'واثقة', 'واقعها،', 'وجد',
        'وضعها', 'وضع', 'واجهت', 'وهمية', 'وحيداً', 'وظائف', 'واقعه', 'واقعها،',
        'وعيك', 'واقعية', 'النفسيّة', 'ورق', 'البيرو', 'أو', 'وحده', 'حول', 'جو',  'هُو',  'وُجود',
    'وُجِد', 'وظيفة', 'ولادته', 'واثق','والدته','وجوه', 'وفقاً','واقعيَّة','وسواس','نحو','اختصاصيو','مقدِّمو'

    ]

    # Step 2: Add special cases that need separation
    separation_rules = [
        (r'(ملحوظاً)\.(قد)', r'\1 \2'),
        (r'(عادةً)\.(قد)', r'\1 \2'),
        (r'(عادةً)\.(في)', r'\1 \2'),
        (r'(الخفيف)(يتميز)', r'\1 \2'),
        (r'(شديدٍ)(يحتاج)', r'\1 \2'),
        (r'(كبيرٍ)\.(في)', r'\1 \2'),
        (r'(دقيقٍ)\.(يجري)', r'\1 \2'),
        (r'(بتحدٍّ)\.(ينبغي)', r'\1 \2'),
        (r'(أقلّ)\.(قدمت)', r'\1 \2'),
        (r'(عادةً)\.(في)', r'\1 \2'),
        (r'(مؤخراً)\.(يضع)', r'\1 \2'),
        (r'(ضوحاً)\.(قَد)', r'\1 \2'),
        (r'(العائليّ)،(كما)', r'\1 \2'),
        (r'(كاملٍ)\.(على)', r'\1 \2'),
        (r'(الانتحار)(عندَ)', r'\1 \2'),
        (r'(الجنسية)(الجندرية)', r'\1 \2'),
        (r'(عادةً)\.(يقوم)', r'\1 \2'),
        (r'(صعوبةً)\.(إذا)', r'\1 \2'),
        (r'(الأزقة)(انظر)', r'\1 \2'),
        (r'(الانتباه)(فرط)', r'\1 \2'),
        (r'(لغوي)(كلامي)', r'\1 \2'),
        (r'(تضرراً)\.(عادةً)', r'\1 \2'),
        (r'(الشخصيَّة)(تبدُّد)', r'\1 \2'),
        (r'(الشخصية)(الغُربَة)', r'\1 \2'),
        (r'(العلاجَ)\.(كما)', r'\1 \2'),
        (r'(الحَدِّيّ)\.(من)', r'\1 \2'),
        (r'(الحديّ)\.(تعرَّض)', r'\1 \2'),
        (r'(أطفالاً)\.(يُسهم)', r'\1 \2'),
        (r'(عادةً)؛(فعلى)', r'\1 \2'),
        (r'(الحَدِّيّ)(يمكن)', r'\1 \2'),
        (r'(بشراسة)؛(أو)', r'\1 \2'),
        (r'(تائهون)(أو)', r'\1 \2'),
        (r'(تاهو)(الفترةً)', r'\1 \2'),
        (r'(النهم)(الشراهة)', r'\1 \2'),
        (r'(عادةً)\.(بالنسبة)', r'\1 \2'),
        (r'(العصبيّ)،(حيث)', r'\1 \2'),
        (r'(فعليّ)\.(إذا)', r'\1 \2'),
        (r'(أو)(فقدان)', r'\1 \2'),
        (r'(تجنّب)(تقييد)', r'\1 \2'),
        (r'(التجنُّبي)(التقييدي)', r'\1 \2'),
        (r'(المُتجنِّب)(المُقيد)', r'\1 \2'),
        (r'(العرَّات)\.(أو)', r'\1 \2'),
        (r'(ضائقة)(ضعف)', r'\1 \2'),
        (r'(مستوي)(التاكد)', r'\1 \2'),
        (r'(توجد)(فيه)', r'\1 \2'),
        (r'(زوايا)(يقف)', r'\1 \2'),
        (r'(الواصل)(من)', r'\1 \2'),
        (r'(الخارجيه)(تنزع)', r'\1 \2'),
        (r'(الراس)(يضغط)', r'\1 \2'),
        (r'(العمل)؛(أو)', r'\1 \2'),
        (r'(متى)\؟(من)', r'\1 \2'),
        (r'(قليلاً)؛(فعلى)', r'\1 \2'),
        (r'(أفكار)(المُعتدي)', r'\1 \2'),
        (r'(النفس)(جرح)', r'\1 \2'),
        (r'(بالاكتئاب)\.(يبدو)', r'\1 \2'),
    (r'(السبب)\.(وجد)', r'\1 \2'),
    (r'(الاكتِئاب)(بعد)', r'\1 \2'),
    (r'(ما)\.(يُصيبُ)', r'\1 \2'),
    (r'(وفاتي)\.(قد)', r'\1 \2'),
    (r'(وصفها)\.(تتمتع)', r'\1 \2'),
    (r'(وجبة)\.(غالبًا)', r'\1 \2'),
    (r'(جداً)\.(فعلى)', r'\1 \2'),
    (r'(عالٍ)\.(على)', r'\1 \2'),
    (r'(وجيزة)\.(على)', r'\1 \2'),
    (r'(ما)\.(غالبًا)', r'\1 \2'),
    (r'(الشخصية)(تبدُّد)', r'\1 \2'),
    (r'(ما)؛(فعلى)', r'\1 \2'),
    (r'(النمط)(تُخفِّف)', r'\1 \2'),
    (r'(عادةً)،(فعلى)', r'\1 \2'),
    (r'(بدنيةً)،(حيث)', r'\1 \2'),
    (r'(وعيه)\.(قد)', r'\1 \2'),
    (r'(وجيزة)\.(بعد)', r'\1 \2'),
    (r'(التوافق)(الرضا)', r'\1 \2'),
    (r'(الآخر)\.(وردًا)', r'\1 \2'),
    (r'(كَثافَتها)(وقد)', r'\1 \2'),
    (r'(مقدار)(الطعام)', r'\1 \2'),
    (r'(أمر)(شائع)', r'\1 \2'),
    (r'(تجنب)(تقييد)', r'\1 \2')
    ]

    # Create a regex pattern that matches all protected words
    protected_pattern = re.compile(
        r'(?:' + '|'.join(map(re.escape, sorted(protected_words, key=len, reverse=True))) + r')'
    )

    #  Apply separation rules before protection
    for pattern, replacement in separation_rules:
        text = re.sub(pattern, replacement, text)

    #  Split the text into protected and non-protected segments
    segments = []
    last_end = 0
    for match in protected_pattern.finditer(text):
        # Add the text before the match
        segments.append((text[last_end:match.start()], False))
        # Add the protected match
        segments.append((match.group(), True))
        last_end = match.end()
    # Add remaining text
    segments.append((text[last_end:], False))

    # Step 5: Process each segment
    processed_text = []
    for segment, is_protected in segments:
        if is_protected:
            processed_text.append(segment)
        else:
            # Apply your original processing to non-protected segments
            # Handle punctuation between words
            temp = re.sub(r'(\w)([.,،؛!?])(\w)', r'\1\2 \3', segment)
            # Original و handling
            temp = re.sub(r'([،؛.])(و)', r'\1 \2', temp)  # Punctuation + و
            temp = re.sub(r'(?<!\S)و(?!\S)', ' و ', temp)  # Standalone و
            temp = re.sub(r'(?<=\s)و(?=\S)', ' و ', temp)  # و at start
            temp = re.sub(r'(?<=\S)و(?=\s)', ' و ', temp)  # و at end
            processed_text.append(temp)

    # Combine all segments
    final_text = ''.join(processed_text)

    # Final tokenization
    tokens = re.findall(r'\S+', final_text)

    with open(output_file, 'w', encoding='utf-8') as f:
        f.write("\n".join(tokens))

unified_arabic_tokenizer("arabic_only_rData.txt", "data_tokens.txt")

# %%
import json

def txt_to_json(input_file, output_file):
    # Read the text file while preserving all content exactly
    with open(input_file, 'r', encoding='utf-8') as f:
        lines = [line.strip() for line in f.readlines()]  # keeps empty lines if present

    # Convert to JSON format without any changes
    data = {
        "original_content": lines,
        "total_lines": len(lines)
    }

    # Write to JSON file
    with open(output_file, 'w', encoding='utf-8') as f:
        json.dump(data, f, ensure_ascii=False, indent=4)  # preserves Arabic/Unicode

# Usage
txt_to_json("data_tokens.txt", "json_data.json")

# %%
import json
import time
from openai import OpenAI
import re

# Initialize client
client = OpenAI(
    base_url="https://openrouter.ai/api/v1",
    api_key="apiKey here"
)

def enforce_json_response(words, response_text):
    try:
        data = json.loads(response_text)
        if isinstance(data, list) and all('word' in item and 'tag' in item for item in data):
            return data
        if isinstance(data, dict) and 'annotations' in data:
            return data['annotations']
    except json.JSONDecodeError:
        pass

    try:
        pattern = r'\[\s*\{[^}]*"word"\s*:\s*"[^"]*"\s*,\s*"tag"\s*:\s*"[^"]*"[^}]*\}\s*(?:,\s*\{[^}]*"word"\s*:\s*"[^"]*"\s*,\s*"tag"\s*:\s*"[^"]*"[^}]*\})*\s*\]'
        match = re.search(pattern, response_text)
        if match:
            return json.loads(match.group(0))
    except:
        pass

    return [{"word": w, "tag": "O"} for w in words]

def get_annotations(words):
    prompt = f"""
    Annotate the following Arabic text using the BIO tagging format
     Categories:
    - B-Disorder (Beginning of a psychological disorder name)
    - I-Disorder (Inside a psychological disorder name)
    - B-Symptom (Beginning of a symptom)
    - I-Symptom (Inside a symptom)
    - B-Treatment (Beginning of a treatment method)
    - I-Treatment (Inside a treatment method)
    - O (Outside any entity)
    Example:
    Input: اضطراب القلق هو حالة طبية تتطلب علاجًا نفسيًا.
    Output (JSON format only, no markdown formatting or extra text):
    {{
        "annotations": [
            {{"word": "اضطراب", "tag": "B-Disorder"}},
            {{"word": "القلق", "tag": "I-Disorder"}},
            {{"word": "هو", "tag": "O"}},
            {{"word": "حالة", "tag": "O"}},
            {{"word": "طبية", "tag": "O"}},
            {{"word": "تتطلب", "tag": "O"}},
            {{"word": "علاجًا", "tag": "B-Treatment"}},
            {{"word": "نفسيًا", "tag": "I-Treatment"}}
        ],
    INPUT: {json.dumps(words, ensure_ascii=False)}
    """
    try:
        response = client.chat.completions.create(
            model="deepseek/deepseek-r1:free",
            messages=[{"role": "system", "content": "Return only valid JSON. No extra text."},
                      {"role": "user", "content": prompt}],
            temperature=0.0,
            max_tokens=2000,
            response_format={"type": "json_object"}
        )
        raw = response.choices[0].message.content
        return enforce_json_response(words, raw)
    except Exception as e:
        print(f"Skipping words due to API error: {words} - Error: {str(e)}")
        return [{"word": w, "tag": "O"} for w in words]

def process_file(input_file, json_output):
    with open(input_file, 'r', encoding='utf-8') as f:
        data = json.load(f)

    words = data.get("original_content", [])
    chunk_size = 5
    all_annotations = []

    for i in range(0, len(words), chunk_size):
        chunk = words[i:i+chunk_size]
        annotations = get_annotations(chunk)
        all_annotations.extend(annotations)
        for item in annotations:
            print(item)  # Print annotation directly
        time.sleep(1.5)

    with open(json_output, 'w', encoding='utf-8') as f:
        json.dump(all_annotations, f, ensure_ascii=False, indent=2)

# Run the processor
process_file("f2.json", "ai2.json")
# Out:
# {'word': '.', 'tag': 'O'}
# {'word': 'ينمو', 'tag': 'O'}
# {'word': 'الأطفال', 'tag': 'O'}
# {'word': 'بوتيرة', 'tag': 'O'}
# {'word': 'خاصة', 'tag': 'O'}
# {'word': 'بهم،', 'tag': 'O'}
# {'word': 'و', 'tag': 'O'}
# {'word': 'لا', 'tag': 'O'}
# {'word': 'يتبع', 'tag': 'O'}
# {'word': 'العديد', 'tag': 'O'}
# {'word': 'منهم', 'tag': 'O'}
# {'word': 'المواعيد', 'tag': 'O'}
# {'word': 'الدقيقة', 'tag': 'O'}
# {'word': 'المذکورة', 'tag': 'O'}
# {'word': 'في', 'tag': 'O'}
# {'word': 'بعض', 'tag': 'O'}
# {'word': 'کتب', 'tag': 'O'}
# {'word': 'الأبوة', 'tag': 'O'}
# {'word': 'و', 'tag': 'O'}
# {'word': 'الأمومة.', 'tag': 'O'}
# {'word': 'و', 'tag': 'O'}
# {'word': 'لکن', 'tag': 'O'}
# {'word': 'عادةً', 'tag': 'O'}
# {'word': 'ما', 'tag': 'O'}
# {'word': 'يظهر', 'tag': 'O'}
# {'word': 'على', 'tag': 'O'}
# {'word': 'الأطفال', 'tag': 'O'}
# {'word': 'المصابين', 'tag': 'O'}
# {'word': 'باضطراب', 'tag': 'B-DISORDER'}
# {'word': 'طيف', 'tag': 'I-DISORDER'}
# {'word': 'التوحد', 'tag': 'B-DISORDER'}
# {'word': 'بعض', 'tag': 'O'}
# {'word': 'علامات', 'tag': 'B-SYMPTOM'}
# {'word': 'تأخر', 'tag': 'B-SYMPTOM'}
# {'word': 'النمو', 'tag': 'I-SYMPTOM'}
# {'word': 'قبل', 'tag': 'O'}
# {'word': 'بلوغ', 'tag': 'O'}
# {'word': 'الثانية', 'tag': 'O'}
# {'word': 'من', 'tag': 'O'}
# {'word': 'العمر،', 'tag': 'O'}
# {'word': 'في', 'tag': 'O'}
# {'word': 'حالة', 'tag': 'O'}
# {'word': 'الشعور', 'tag': 'B-SYMPTOM'}
# {'word': 'بقلق', 'tag': 'I-SYMPTOM'}
# {'word': 'حيال', 'tag': 'O'}
# {'word': 'نمو', 'tag': 'B-SYMPTOM'}
# {'word': 'الطفل', 'tag': 'O'}
# {'word': 'أو', 'tag': 'O'}
# {'word': 'الاشتباه', 'tag': 'O'}
# {'word': 'في', 'tag': 'O'}
# {'word': 'إمکانية', 'tag': 'O'}
# {'word': 'إصابة', 'tag': 'O'}
# {'word': 'الطفل', 'tag': 'O'}
# {'word': 'باضطراب', 'tag': 'O'}
# {'word': 'طيف', 'tag': 'O'}
# {'word': 'التوحد،', 'tag': 'B-DISORDER'}
# {'word': 'يرجى', 'tag': 'O'}
# {'word': 'الإعراب', 'tag': 'O'}
# {'word': 'عن', 'tag': 'O'}
# {'word': 'مخاوفک', 'tag': 'B-SYMPTOM'}
# {'word': 'للطبيب.', 'tag': 'O'}
# {'word': 'کما', 'tag': 'O'}
# {'word': 'أن', 'tag': 'O'}
# {'word': 'الأعراض', 'tag': 'B-SYMPTOM'}
# {'word': 'المرتبطة', 'tag': 'I-SYMPTOM'}
# {'word': 'بالاضطراب', 'tag': 'B-DISORDER'}
# {'word': 'قد', 'tag': 'O'}
# {'word': 'تکون', 'tag': 'O'}
# {'word': 'مرتبطة', 'tag': 'O'}
# {'word': 'کذلک', 'tag': 'O'}
# {'word': 'باضطرابات', 'tag': 'B-DISORDER'}
# {'word': 'النمو', 'tag': 'I-DISORDER'}
# {'word': 'الأخرى،', 'tag': 'O'}
# {'word': 'غالبًا', 'tag': 'O'}
# {'word': 'ما', 'tag': 'O'}
# {'word': 'تظهر', 'tag': 'O'}
# {'word': 'علامات', 'tag': 'B-SYMPTOM'}
# {'word': 'اضطراب', 'tag': 'B-DISORDER'}
# {'word': 'طيف', 'tag': 'I-DISORDER'}
# {'word': 'التوحد', 'tag': 'I-DISORDER'}
# {'word': 'مبكرًا', 'tag': 'O'}
# {'word': 'في', 'tag': 'O'}
# {'word': 'مرحلة', 'tag': 'O'}
# {'word': 'النمو', 'tag': 'O'}
# {'word': 'عندما', 'tag': 'O'}
# {'word': 'يکون', 'tag': 'O'}
# {'word': 'هناک', 'tag': 'O'}
# {'word': 'تأخر', 'tag': 'B-SYMPTOM'}
# {'word': 'واضح', 'tag': 'O'}
# {'word': 'في', 'tag': 'O'}
# {'word': 'مهارات', 'tag': 'O'}
# {'word': 'و', 'tag': 'O'}
# {'word': 'التفاعلات', 'tag': 'O'}
# {'word': 'الاجتماعية.', 'tag': 'O'}
# {'word': 'ربما', 'tag': 'O'}
# {'word': 'يوصي', 'tag': 'O'}
# {'word': 'الطبيب', 'tag': 'O'}
# {'word': 'بإجراء', 'tag': 'O'}
# {'word': 'اختبارات', 'tag': 'B-TREATMENT'}
# {'word': 'النمو', 'tag': 'I-TREATMENT'}
# {'word': 'لتحديد', 'tag': 'O'}
# {'word': 'ما', 'tag': 'O'}
# {'word': 'إذا', 'tag': 'O'}
# {'word': 'کان', 'tag': 'O'}
# {'word': 'الطفل', 'tag': 'O'}
# {'word': 'يعاني', 'tag': 'O'}
# {'word': 'تأخرًا', 'tag': 'B-SYMPTOM'}
# {'word': 'في', 'tag': 'O'}
# {'word': 'المهارات', 'tag': 'I-SYMPTOM'}
# {'word': 'الإدراکية', 'tag': 'I-SYMPTOM'}
# {'word': 'و', 'tag': 'O'}
# {'word': 'الاجتماعية', 'tag': 'O'}
# {'word': 'و', 'tag': 'O'}
# {'word': 'مهارات', 'tag': 'O'}
# {'word': 'أم', 'tag': 'O'}
# {'word': 'لا', 'tag': 'O'}
# {'word': '.إن', 'tag': 'O'}
# {'word': 'وجود', 'tag': 'O'}
# {'word': 'تناقضات', 'tag': 'O'}
# {'word': 'في', 'tag': 'O'}
# {'word': 'نظام', 'tag': 'O'}
# {'word': 'القيم', 'tag': 'O'}
# {'word': 'و', 'tag': 'O'}
# {'word': 'المعايير', 'tag': 'O'}
# {'word': 'الاجتماعية', 'tag': 'O'}
# {'word': 'المتمثلة', 'tag': 'O'}
# {'word': 'في', 'tag': 'O'}
# {'word': 'ترعرع', 'tag': 'O'}
# {'word': 'الطفل', 'tag': 'O'}
# {'word': 'في', 'tag': 'O'}
# {'word': 'جو', 'tag': 'O'}
# {'word': 'متسلط', 'tag': 'O'}
# {'word': 'يغيب', 'tag': 'O'}
# {'word': 'فيه', 'tag': 'O'}
# {'word': 'مبدأ', 'tag': 'O'}
# {'word': 'الحوار', 'tag': 'O'}
# {'word': 'الهادئ', 'tag': 'O'}
# {'word': 'و', 'tag': 'O'}
# {'word': 'تأثير', 'tag': 'O'}
# {'word': 'الثقافة', 'tag': 'O'}
# {'word': 'السائدة', 'tag': 'O'}
# {'word': 'في', 'tag': 'O'}
# {'word': 'المجتمع', 'tag': 'O'}
# {'word': 'الذي', 'tag': 'O'}
# {'word': 'يهمل', 'tag': 'O'}
# {'word': 'استخدام', 'tag': 'O'}
# {'word': 'الكحول', 'tag': 'B-DISORDER'}
# {'word': 'و', 'tag': 'O'}
# {'word': 'المخدرات', 'tag': 'B-DISORDER'}
# {'word': 'من', 'tag': 'O'}
# {'word': 'قبل', 'tag': 'O'}
# {'word': 'الأب', 'tag': 'O'}
# {'word': 'أو', 'tag': 'O'}
# {'word': 'الزوج،', 'tag': 'O'}
# {'word': 'يساعد', 'tag': 'O'}
# {'word': 'على', 'tag': 'O'}
# {'word': 'إحداث', 'tag': 'O'}
# {'word': 'اضطراب', 'tag': 'B-DISORDER'}
# {'word': 'في', 'tag': 'O'}
# {'word': 'نفس', 'tag': 'O'}
# {'word': 'الطفل', 'tag': 'O'}
# {'word': 'و', 'tag': 'O'}
# {'word': 'سلوكه.', 'tag': 'B-SYMPTOM'}
# {'word': 'و', 'tag': 'O'}
# {'word': 'تكون', 'tag': 'O'}
# {'word': 'نتيجة', 'tag': 'O'}
# {'word': 'ذلك', 'tag': 'O'}
# {'word': 'إقتداء', 'tag': 'O'}
# {'word': 'الطفل', 'tag': 'O'}
# {'word': 'المراهق', 'tag': 'O'}
# {'word': 'بعادات', 'tag': 'O'}
# {'word': 'أبيه', 'tag': 'O'}
# {'word': 'السيئة', 'tag': 'O'}
# {'word': 'و', 'tag': 'O'}
# {'word': 'المخالفة', 'tag': 'O'}
# {'word': 'للأعراف', 'tag': 'O'}
# {'word': 'و', 'tag': 'O'}
# {'word': 'الدين', 'tag': 'O'}
# {'word': 'ي،', 'tag': 'O'}
# {'word': 'مما', 'tag': 'O'}
# {'word': 'يؤدي', 'tag': 'O'}
# {'word': 'به', 'tag': 'O'}
# {'word': 'إلى', 'tag': 'O'}
# {'word': 'الانعزالية', 'tag': 'B-SYMPTOM'}
# {'word': 'و', 'tag': 'O'}
# {'word': 'الاغتراب', 'tag': 'B-SYMPTOM'}
# {'word': 'و', 'tag': 'O'}
# {'word': 'فقدان', 'tag': 'B-SYMPTOM'}
# {'word': 'الثقة', 'tag': 'I-SYMPTOM'}
# {'word': 'بالذات', 'tag': 'I-SYMPTOM'}
# {'word': 'إلى', 'tag': 'O'}
# {'word': 'حد', 'tag': 'O'}
# {'word': 'الانفعال', 'tag': 'B-SYMPTOM'}
# {'word': 'الحاد', 'tag': 'I-SYMPTOM'}
# {'word': 'و', 'tag': 'O'}
# {'word': 'العدوانية.', 'tag': 'B-SYMPTOM'}
# {'word': 'ففي', 'tag': 'O'}
# {'word': 'هذا', 'tag': 'O'}
# {'word': 'البحث،', 'tag': 'O'}
# {'word': 'نحاول', 'tag': 'O'}
# {'word': 'الكشف', 'tag': 'O'}
# {'word': 'عن', 'tag': 'O'}
# {'word': 'الأسباب', 'tag': 'O'}
# {'word': 'و', 'tag': 'O'}
# {'word': 'العوامل', 'tag': 'O'}
# {'word': 'التي', 'tag': 'O'}
# {'word': 'تؤدي', 'tag': 'O'}
# {'word': 'إلى', 'tag': 'O'}
# {'word': 'نشأة', 'tag': 'O'}
# {'word': 'الاضطرابات', 'tag': 'B-DISORDER'}
# {'word': 'النفسية', 'tag': 'B-DISORDER'}
# {'word': 'و', 'tag': 'O'}
# {'word': 'السلوكية', 'tag': 'I-DISORDER'}
# {'word': 'لدى', 'tag': 'O'}
# {'word': 'الطفل،', 'tag': 'O'}
# {'word': 'الذي', 'tag': 'O'}
# {'word': 'يعاني', 'tag': 'O'}
# {'word': 'يوميا', 'tag': 'O'}
# {'word': 'من', 'tag': 'O'}
# {'word': 'إدمان', 'tag': 'B-DISORDER'}
# {'word': 'الكحول', 'tag': 'B-DISORDER'}
# {'word': 'المخدرات', 'tag': 'B-DISORDER'}
# {'word': 'و', 'tag': 'O'}
# {'word': 'كذلك', 'tag': 'O'}
# {'word': 'تسليط', 'tag': 'O'}
# {'word': 'الضوء', 'tag': 'O'}
# {'word': 'على', 'tag': 'O'}
# {'word': 'مدى', 'tag': 'O'}
# {'word': 'تأثير', 'tag': 'O'}
# {'word': 'هذه', 'tag': 'O'}
# {'word': 'الحالات', 'tag': 'B-DISORDER'}
# {'word': 'النفسية', 'tag': 'I-DISORDER'}
# {'word': 'و', 'tag': 'O'}
# {'word': 'السلوكية', 'tag': 'B-DISORDER'}
# {'word': 'المرضية', 'tag': 'I-DISORDER'}
# {'word': 'على', 'tag': 'O'}
# {'word': 'شخصيته', 'tag': 'O'}
# {'word': 'في', 'tag': 'O'}
# {'word': 'سن', 'tag': 'O'}
# {'word': 'المراهقة', 'tag': 'O'}
# {'word': 'و', 'tag': 'O'}
# {'word': 'الرشد', 'tag': 'O'}
# {'word': '.هدفت', 'tag': 'O'}
# {'word': 'الدراسة', 'tag': 'O'}
# {'word': 'الحالية', 'tag': 'O'}
# {'word': 'معرفة', 'tag': 'O'}
# {'word': 'مستوى', 'tag': 'O'}
# Skipping words due to API error: ['الاضطرابات', 'النفسية', 'لدى', 'الطفل', 'المعاق'] - Error: 'NoneType' object is not subscriptable
# {'word': 'الاضطرابات', 'tag': 'O'}
# {'word': 'النفسية', 'tag': 'O'}
# {'word': 'لدى', 'tag': 'O'}
# {'word': 'الطفل', 'tag': 'O'}
# {'word': 'المعاق', 'tag': 'O'}
# Skipping words due to API error: ['ذهنيا', 'من', 'وجهة', 'نظر', 'الاخصائيين'] - Error: 'NoneType' object is not subscriptable
# {'word': 'ذهنيا', 'tag': 'O'}
# {'word': 'من', 'tag': 'O'}
# {'word': 'وجهة', 'tag': 'O'}
# {'word': 'نظر', 'tag': 'O'}
# {'word': 'الاخصائيين', 'tag': 'O'}
# Skipping words due to API error: ['النفسانيين،', 'و', 'كذا', 'الفروق', 'في'] - Error: 'NoneType' object is not subscriptable
# {'word': 'النفسانيين،', 'tag': 'O'}
# {'word': 'و', 'tag': 'O'}
# {'word': 'كذا', 'tag': 'O'}
# {'word': 'الفروق', 'tag': 'O'}
# {'word': 'في', 'tag': 'O'}
# Skipping words due to API error: ['مستوى', 'الاضطرابات', 'النفسية', 'لدى', 'الأطفال'] - Error: 'NoneType' object is not subscriptable
# {'word': 'مستوى', 'tag': 'O'}
# {'word': 'الاضطرابات', 'tag': 'O'}
# {'word': 'النفسية', 'tag': 'O'}
# {'word': 'لدى', 'tag': 'O'}
# {'word': 'الأطفال', 'tag': 'O'}
# Skipping words due to API error: ['ذوي', 'الإعاقة', 'الذهنية', 'تبعا', 'لمتغير'] - Error: 'NoneType' object is not subscriptable
# {'word': 'ذوي', 'tag': 'O'}
# {'word': 'الإعاقة', 'tag': 'O'}
# {'word': 'الذهنية', 'tag': 'O'}
# {'word': 'تبعا', 'tag': 'O'}
# {'word': 'لمتغير', 'tag': 'O'}
# Skipping words due to API error: ['نوع', 'الإعاقة', 'و', 'جنس', 'الطفل'] - Error: 'NoneType' object is not subscriptable
# {'word': 'نوع', 'tag': 'O'}
# {'word': 'الإعاقة', 'tag': 'O'}
# {'word': 'و', 'tag': 'O'}
# {'word': 'جنس', 'tag': 'O'}
# {'word': 'الطفل', 'tag': 'O'}
# Skipping words due to API error: ['المعاق.', 'تكونت', 'عينة', 'الدراسة', 'من'] - Error: 'NoneType' object is not subscriptable
# {'word': 'المعاق.', 'tag': 'O'}
# {'word': 'تكونت', 'tag': 'O'}
# {'word': 'عينة', 'tag': 'O'}
# {'word': 'الدراسة', 'tag': 'O'}
# {'word': 'من', 'tag': 'O'}
# Skipping words due to API error: ['48', 'طفلا', 'ممن', 'يعانون', 'من'] - Error: 'NoneType' object is not subscriptable
# {'word': '48', 'tag': 'O'}
# {'word': 'طفلا', 'tag': 'O'}
# {'word': 'ممن', 'tag': 'O'}
# {'word': 'يعانون', 'tag': 'O'}
# {'word': 'من', 'tag': 'O'}
# Skipping words due to API error: ['إعاقة', 'عقلية.', 'تم', 'استخدام', 'المنهج'] - Error: 'NoneType' object is not subscriptable
# {'word': 'إعاقة', 'tag': 'O'}
# {'word': 'عقلية.', 'tag': 'O'}
# {'word': 'تم', 'tag': 'O'}
# {'word': 'استخدام', 'tag': 'O'}
# {'word': 'المنهج', 'tag': 'O'}
# Skipping words due to API error: ['الوصفي', 'باستخدام', 'مقياس', 'الاضطرابات', 'النفسية'] - Error: 'NoneType' object is not subscriptable
# {'word': 'الوصفي', 'tag': 'O'}
# {'word': 'باستخدام', 'tag': 'O'}
# {'word': 'مقياس', 'tag': 'O'}
# {'word': 'الاضطرابات', 'tag': 'O'}
# {'word': 'النفسية', 'tag': 'O'}
# Skipping words due to API error: ['لذوي', 'الإعاقة', 'المزدوجة', 'البصرية', 'و'] - Error: 'NoneType' object is not subscriptable
# {'word': 'لذوي', 'tag': 'O'}
# {'word': 'الإعاقة', 'tag': 'O'}
# {'word': 'المزدوجة', 'tag': 'O'}
# {'word': 'البصرية', 'tag': 'O'}
# {'word': 'و', 'tag': 'O'}
# Skipping words due to API error: ['العقلية', 'البسيطة', 'للباحثة', 'للباحثة', 'فوليت'] - Error: 'NoneType' object is not subscriptable
# {'word': 'العقلية', 'tag': 'O'}
# {'word': 'البسيطة', 'tag': 'O'}
# {'word': 'للباحثة', 'tag': 'O'}
# {'word': 'للباحثة', 'tag': 'O'}
# {'word': 'فوليت', 'tag': 'O'}
# Skipping words due to API error: ['و', 'آخرون', '.', 'و', 'لقد'] - Error: 'NoneType' object is not subscriptable
# {'word': 'و', 'tag': 'O'}
# {'word': 'آخرون', 'tag': 'O'}
# {'word': '.', 'tag': 'O'}
# {'word': 'و', 'tag': 'O'}
# {'word': 'لقد', 'tag': 'O'}
# Skipping words due to API error: ['دلت', 'النتائج', 'على', 'وجود', 'مستويات'] - Error: 'NoneType' object is not subscriptable
# {'word': 'دلت', 'tag': 'O'}
# {'word': 'النتائج', 'tag': 'O'}
# {'word': 'على', 'tag': 'O'}
# {'word': 'وجود', 'tag': 'O'}
# {'word': 'مستويات', 'tag': 'O'}
# Skipping words due to API error: ['منخفضة', 'من', 'الاضطرابات', 'النفسية', 'لدى'] - Error: 'NoneType' object is not subscriptable
# {'word': 'منخفضة', 'tag': 'O'}
# {'word': 'من', 'tag': 'O'}
# {'word': 'الاضطرابات', 'tag': 'O'}
# {'word': 'النفسية', 'tag': 'O'}
# {'word': 'لدى', 'tag': 'O'}
# Skipping words due to API error: ['الأطفال', 'المعاقين،', 'و', 'كذا', 'عدم'] - Error: 'NoneType' object is not subscriptable
# {'word': 'الأطفال', 'tag': 'O'}
# {'word': 'المعاقين،', 'tag': 'O'}
# {'word': 'و', 'tag': 'O'}
# {'word': 'كذا', 'tag': 'O'}
# {'word': 'عدم', 'tag': 'O'}
# Skipping words due to API error: ['وجود', 'فروق', 'متباينة', 'مستوى', 'الاضطرابات'] - Error: 'NoneType' object is not subscriptable
# {'word': 'وجود', 'tag': 'O'}
# {'word': 'فروق', 'tag': 'O'}
# {'word': 'متباينة', 'tag': 'O'}
# {'word': 'مستوى', 'tag': 'O'}
# {'word': 'الاضطرابات', 'tag': 'O'}
# Skipping words due to API error: ['النفسية', 'لدى', 'الأطفال', 'ذوي', 'الإعاقة'] - Error: 'NoneType' object is not subscriptable
# {'word': 'النفسية', 'tag': 'O'}
# {'word': 'لدى', 'tag': 'O'}
# {'word': 'الأطفال', 'tag': 'O'}
# {'word': 'ذوي', 'tag': 'O'}
# {'word': 'الإعاقة', 'tag': 'O'}
# Skipping words due to API error: ['الذهنية', 'تبعا', 'لمتغير', 'نوع', 'الإعاقة'] - Error: 'NoneType' object is not subscriptable
# {'word': 'الذهنية', 'tag': 'O'}
# {'word': 'تبعا', 'tag': 'O'}
# {'word': 'لمتغير', 'tag': 'O'}
# {'word': 'نوع', 'tag': 'O'}
# {'word': 'الإعاقة', 'tag': 'O'}
# Skipping words due to API error: ['و', 'جنس', 'الطفل', 'المعاق', 'الاكتئاب'] - Error: 'NoneType' object is not subscriptable
# {'word': 'و', 'tag': 'O'}
# {'word': 'جنس', 'tag': 'O'}
# {'word': 'الطفل', 'tag': 'O'}
# {'word': 'المعاق', 'tag': 'O'}
# {'word': 'الاكتئاب', 'tag': 'O'}
# Skipping words due to API error: ['و', 'اضطراب', 'اختلال', 'المزاج', 'عند'] - Error: 'NoneType' object is not subscriptable
# {'word': 'و', 'tag': 'O'}
# {'word': 'اضطراب', 'tag': 'O'}
# {'word': 'اختلال', 'tag': 'O'}
# {'word': 'المزاج', 'tag': 'O'}
# {'word': 'عند', 'tag': 'O'}
# Skipping words due to API error: ['الأطفال', 'و', 'المراهقين', 'دليل', 'الأعراض'] - Error: 'NoneType' object is not subscriptable
# {'word': 'الأطفال', 'tag': 'O'}
# {'word': 'و', 'tag': 'O'}
# {'word': 'المراهقين', 'tag': 'O'}
# {'word': 'دليل', 'tag': 'O'}
# {'word': 'الأعراض', 'tag': 'O'}
# Skipping words due to API error: ['حول', 'اضطرابات', 'الصحَّة', 'النفسية', 'عندَ'] - Error: 'NoneType' object is not subscriptable
# {'word': 'حول', 'tag': 'O'}
# {'word': 'اضطرابات', 'tag': 'O'}
# {'word': 'الصحَّة', 'tag': 'O'}
# {'word': 'النفسية', 'tag': 'O'}
# {'word': 'عندَ', 'tag': 'O'}
# Skipping words due to API error: ['الأطفال', 'و', 'المراهقين', 'الاكتئاب', 'و'] - Error: 'NoneType' object is not subscriptable
# {'word': 'الأطفال', 'tag': 'O'}
# {'word': 'و', 'tag': 'O'}
# {'word': 'المراهقين', 'tag': 'O'}
# {'word': 'الاكتئاب', 'tag': 'O'}
# {'word': 'و', 'tag': 'O'}
# Skipping words due to API error: ['اضطراب', 'اختلال', 'المزاج', 'عند', 'الأطفال'] - Error: 'NoneType' object is not subscriptable
# {'word': 'اضطراب', 'tag': 'O'}
# {'word': 'اختلال', 'tag': 'O'}
# {'word': 'المزاج', 'tag': 'O'}
# {'word': 'عند', 'tag': 'O'}
# {'word': 'الأطفال', 'tag': 'O'}
# Skipping words due to API error: ['و', 'المراهقين', 'الاكتئاب', 'و', 'اضطراب'] - Error: 'NoneType' object is not subscriptable
# {'word': 'و', 'tag': 'O'}
# {'word': 'المراهقين', 'tag': 'O'}
# {'word': 'الاكتئاب', 'tag': 'O'}
# {'word': 'و', 'tag': 'O'}
# {'word': 'اضطراب', 'tag': 'O'}
# Skipping words due to API error: ['اختلال', 'المزاج', 'عند', 'الأطفال', 'و'] - Error: 'NoneType' object is not subscriptable
# {'word': 'اختلال', 'tag': 'O'}
# {'word': 'المزاج', 'tag': 'O'}
# {'word': 'عند', 'tag': 'O'}
# {'word': 'الأطفال', 'tag': 'O'}
# {'word': 'و', 'tag': 'O'}
# Skipping words due to API error: ['المراهقين', 'حسب', 'ينطوي', 'الاكتئاب', 'على'] - Error: 'NoneType' object is not subscriptable
# {'word': 'المراهقين', 'tag': 'O'}
# {'word': 'حسب', 'tag': 'O'}
# {'word': 'ينطوي', 'tag': 'O'}
# {'word': 'الاكتئاب', 'tag': 'O'}
# {'word': 'على', 'tag': 'O'}
# Skipping words due to API error: ['شعور', 'بالحزن', 'أو', 'الهياج', 'عند'] - Error: 'NoneType' object is not subscriptable
# {'word': 'شعور', 'tag': 'O'}
# {'word': 'بالحزن', 'tag': 'O'}
# {'word': 'أو', 'tag': 'O'}
# {'word': 'الهياج', 'tag': 'O'}
# {'word': 'عند', 'tag': 'O'}
# Skipping words due to API error: ['الأطفال', 'و', 'المراهقين،'] - Error: 'NoneType' object is not subscriptable
# {'word': 'الأطفال', 'tag': 'O'}
# {'word': 'و', 'tag': 'O'}
# {'word': 'المراهقين،', 'tag': 'O'}

# %%
import json
import string

# Define Arabic and English punctuation
punctuations = set(string.punctuation) | {'،', '؛', '؟', '«', '»', '“', '”', '‘', '’', '…'}

def clean_word(word):
    """Remove all punctuation from a word"""
    if not isinstance(word, str):
        return word
    return ''.join(char for char in word if char not in punctuations)

def process_json_file(input_filename, output_filename, key="word"):
    """
    Process a JSON file to remove punctuation from specified key
    and save the cleaned version
    """
    try:
        with open(input_filename, 'r', encoding='utf-8') as f:
            data = json.load(f)

        # Process the data structure
        if isinstance(data, list):
            cleaned_data = []
            for item in data:
                if isinstance(item, dict) and key in item:
                    cleaned = clean_word(item[key])
                    if cleaned:  # Only keep non-empty results
                        new_item = item.copy()
                        new_item[key] = cleaned
                        cleaned_data.append(new_item)
                else:
                    cleaned_data.append(item)
        elif isinstance(data, dict):
            cleaned_data = {}
            for k, v in data.items():
                if k == key:
                    cleaned = clean_word(v)
                    if cleaned:
                        cleaned_data[k] = cleaned
                else:
                    cleaned_data[k] = v
        else:
            raise ValueError("Unsupported JSON structure")

        # Save cleaned data
        with open(output_filename, 'w', encoding='utf-8') as f:
            json.dump(cleaned_data, f, ensure_ascii=False, indent=2)

        print(f"Successfully processed {input_filename} -> {output_filename}")

    except Exception as e:
        print(f"Error processing {input_filename}: {str(e)}")
        raise

# Process both files
if __name__ == "__main__":
    # Input and output filenames (same directory)
    files_to_process = [
        ("HumanAnnotation.json", "Human_Annotation.json"),
        ("AiAnnotation.json", "Ai_Annotation.json")
    ]

    for input_file, output_file in files_to_process:
        process_json_file(input_file, output_file)
# Out:
# Successfully processed HumanAnnotation.json -> Human_Annotation.json
# Successfully processed AiAnnotation.json -> Ai_Annotation.json

# %%
import json

def compare_annotations(human_file, ai_file, output_file):
    # Load JSON files
    with open(human_file, 'r', encoding='utf-8') as f:
        human_data = json.load(f)
    with open(ai_file, 'r', encoding='utf-8') as f:
        ai_data = json.load(f)

    results = {
        'entries': [],
        'counts': {'TP': 0, 'FP': 0, 'TN': 0, 'FN': 0},
        'metrics': {}
    }

    entity_types = {'DISORDER', 'SYMPTOM', 'TREATMENT'}
    bio_prefixes = ('B-', 'I-')

    for human_entry, ai_entry in zip(human_data, ai_data):
        # Extract word and tags (now using 'word' key)
        word = human_entry.get('word', '')  # <-- FIXED: Changed from 'text' to 'word'
        human_tag = human_entry.get('tag', 'O').upper()
        ai_tag = ai_entry.get('tag', 'O').upper()

        # Determine if human tag is an entity
        is_human_entity = (human_tag in entity_types or
                          human_tag.startswith(bio_prefixes))

        # Classify prediction
        if is_human_entity:
            if ai_tag == human_tag:
                result = 'TP'
            elif ai_tag == 'O':
                result = 'FN'
            else:  # AI predicted a different entity type
                result = 'FP'
        else:  # Human tag is 'O'
            if ai_tag == 'O':
                result = 'TN'
            else:  # AI predicted an entity where none exists
                result = 'FP'

        # Update counts
        results['counts'][result] += 1

        # Store detailed comparison
        results['entries'].append({
            'word': word,  # Now correctly populated
            'human_annotation': human_tag,
            'ai_annotation': ai_tag,
            'prediction': result
        })

    # Calculate metrics
    TP, FP, FN = results['counts']['TP'], results['counts']['FP'], results['counts']['FN']
    precision = TP / (TP + FP) if (TP + FP) > 0 else 0
    recall = TP / (TP + FN) if (TP + FN) > 0 else 0
    f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0

    results['metrics'] = {
        'precision': round(precision, 4),
        'recall': round(recall, 4),
        'f1_score': round(f1, 4)
    }

    # Save results
    with open(output_file, 'w', encoding='utf-8') as f:
        json.dump(results, f, indent=2, ensure_ascii=False)

    print(f" Results saved to {output_file}")
    print(f"TP: {results['counts']['TP']}, FP: {results['counts']['FP']}, TN: {results['counts']['TN']}, FN: {results['counts']['FN']}")
    print(f"Precision: {results['metrics']['precision']:.4f}, Recall: {results['metrics']['recall']:.4f}, F1: {results['metrics']['f1_score']:.4f}")

# Example usage
compare_annotations(
    human_file='Human_Annotation.json',
    ai_file='Ai_Annotation.json',
    output_file='comparison_results.json'
)
# Out:
#  Results saved to comparison_results.json
# TP: 5804, FP: 19180, TN: 70603, FN: 11472
# Precision: 0.2323, Recall: 0.3360, F1: 0.2747
